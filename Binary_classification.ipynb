# %% [markdown]
# <font color=lightblue size=5>Predicting if a person would buy life insurnace based on his age using logistic regression</font><br>
# <br>
# <font color=yellow>
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).
# </font>

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance,marker=".")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)
x_test
# Out:
#     age
# 0    22
# 17   58
# 4    46
# 24   50
# 14   49
# 22   40

# %%
y_test
# Out:
# 0     0
# 17    1
# 4     1
# 24    1
# 14    1
# 22    1
# Name: bought_insurance, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 0    22
# 17   58
# 4    46
# 24   50
# 14   49
# 22   40

# %%
y_predected = model.predict(x_test)
y_predected
# Out:
# array([0, 1, 1, 1, 1, 0])

# %%
model.predict_proba(x_test)
# Out:
# array([[0.92037415, 0.07962585],
#        [0.13943187, 0.86056813],
#        [0.40190577, 0.59809423],
#        [0.29490221, 0.70509779],
#        [0.32013484, 0.67986516],
#        [0.57779114, 0.42220886]])

# %%
model.score(x_test,y_test)
# Out:
# 0.8333333333333334

# %% [markdown]
# model.coef_ indicates value of m in y = m*x + b equation

# %%
model.coef_
# Out:
# array([[0.1185405]])

# %%
model.intercept_ #b in y=mx + b
# Out:
# array([-5.05533252])

# %% [markdown]
# Sigmoid function

# %%
import math
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age):
    z = 0.042 * age - 1.53
    y = sigmoid(z)
    print(z)
    return y

# %%
prediction_function(40)
# Out:
# 0.15000000000000013
# 0.5374298453437496
